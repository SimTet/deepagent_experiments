# %%
from src.research_agent import agent

# %%
result = agent.invoke(
    input={
        "messages": [
            {
                "role": "user",
                "content": "what do you think will be the next big llm release? consider and compare the latest news of google, openai, microsoft and anthropic.",
            }
        ]
    }
)

# %%
for msg in result["messages"]:
    print(msg)

# %%
result["messages"][-1].content
